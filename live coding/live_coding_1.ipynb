# %% [markdown]
# DSI live coding session 2025-07-02

# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Basic figure with matplotlib 
np.random.seed(613)
x = np.arange(50)
y = np.random.randint(0, 100,50)

fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y)

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.bar(x,y)
# Out:
# <BarContainer object of 50 artists>

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y)

# %%
#histogram
fig, ax = plt.subplots(figsize=(5, 3))
ax.hist(y)
# Out:
# (array([4., 6., 2., 5., 7., 6., 4., 3., 9., 4.]),
#  array([ 6. , 15.2, 24.4, 33.6, 42.8, 52. , 61.2, 70.4, 79.6, 88.8, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
# Adding labels to the line graph

# modifying labels and titles
font1 = {'family':'sans-serif','color':'blue','size':20}
font2 = {'family':'monospace','color':'green','size':14}

fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y)

ax.set_title('Total growth over time', fontdict = font1, loc = 'left')
ax.set_ylabel('Total growth', fontdict = font2)
ax.set_xlabel('Years since start', fontdict = font2)
# Out:
# Text(0.5, 0, 'Years since start')

# %%
# Modifying data points - 1

fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x, 
           y, 
           marker='*',
           color = 'indigo')

# %%
# Modifying data points - 2
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x, 
        y, 
        marker='*',
        color = '#7425B9',
        linestyle = "--",
        linewidth = 2,
        markersize = 12,
        markeredgecolor = '#FA9359',
        markerfacecolor = '#000000')
ax.grid(axis = 'x', linestyle = '--', color = 'pink')  # adding grid lines - which I really do not like

# %%
# Recreating a plot from the Python graph gallery
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data
path = 'https://raw.githubusercontent.com/holtzy/The-Python-Graph-Gallery/master/static/data/iris.csv'
df = pd.read_csv(path)

# Plot with diamond markers
fig, ax = plt.subplots(figsize=(8, 6))
sns.regplot(
    x=df["sepal_length"],
    y=df["sepal_width"],
    marker='D',  # Diamond
    scatter_kws={'s': 70, 'color': '#5A189A'},  # Adjust size and color as you like
    line_kws={"color": "red", "linewidth": 1.5},
    ax=ax
)


# Rename axes
ax.set_xlabel("Sepal Length (cm)")
ax.set_ylabel("Sepal Width (cm)")

plt.show()
